# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv(r'D:\DSF\PROJECTPRO\MEDICAL_PROJECTS\finalised_anemia.csv')

# %%
df
# Out:
#            ID  age  sex  Retic_count  Bilirubin_count  LDH_count Coombs_test  \
# 0           0   51    0         0.40             0.51      135.0    not_done
# 1           1   15    1         0.08             0.22       23.0    not_done
# 2           2   74    1         2.18             0.58       77.0    not_done
# 3           3   66    0         0.38             0.60       25.0    not_done
# 4           4   30    1         4.62             3.87      628.0    positive
# ..        ...  ...  ...          ...              ...        ...         ...
# 976       995   38    0         1.91             0.27      127.0    not_done
# 977       996   70    0         2.28             0.58      109.0    not_done
# 978       997   41    1         0.42             0.77      120.0    not_done
# 979       998   54    1         0.08             0.31       54.0    not_done
# 980  not_done   64    1         0.20             0.44      118.0    not_done
#
# ...

# %%
df
# Out:
#        ID  age  sex  Retic_count  Bilirubin_count  LDH_count Coombs_test  \
# 0       0   51    0         0.40             0.51      135.0        1000
# 1       1   15    1         0.08             0.22       23.0        1000
# 2       2   74    1         2.18             0.58       77.0        1000
# 3       3   66    0         0.38             0.60       25.0        1000
# 4       4   30    1         4.62             3.87      628.0    positive
# ..    ...  ...  ...          ...              ...        ...         ...
# 976   995   38    0         1.91             0.27      127.0        1000
# 977   996   70    0         2.28             0.58      109.0        1000
# 978   997   41    1         0.42             0.77      120.0        1000
# 979   998   54    1         0.08             0.31       54.0        1000
# 980  1000   64    1         0.20             0.44      118.0        1000
#
#     Peripheral_Smear  Ferritin_level Hb_electrophoresis  \
# ...

# %%
def convert_Peripheral_Smear(x):
    if x == 'Microcytic':               #low
        return 7
    elif x == 'Normocytic':             #normal
        return 8
    else:
        return 9                        #high

# %%
df['Peripheral_Smear'] = df['Peripheral_Smear'].apply(lambda x: convert_Peripheral_Smear(x))

# %%
df
# Out:
#        ID  age  sex  Retic_count  Bilirubin_count  LDH_count Coombs_test  \
# 0       0   51    0         0.40             0.51      135.0        1000
# 1       1   15    1         0.08             0.22       23.0        1000
# 2       2   74    1         2.18             0.58       77.0        1000
# 3       3   66    0         0.38             0.60       25.0        1000
# 4       4   30    1         4.62             3.87      628.0    positive
# ..    ...  ...  ...          ...              ...        ...         ...
# 976   995   38    0         1.91             0.27      127.0        1000
# 977   996   70    0         2.28             0.58      109.0        1000
# 978   997   41    1         0.42             0.77      120.0        1000
# 979   998   54    1         0.08             0.31       54.0        1000
# 980  1000   64    1         0.20             0.44      118.0        1000
#
#      Peripheral_Smear  Ferritin_level Hb_electrophoresis  \
# ...

# %%
df['Coombs_test'].value_counts()
# Out:
# 1000        821
# negative     84
# positive     76
# Name: Coombs_test, dtype: int64

# %%
def convert_Coombs_test(x):
    if x == 'positive':              
        return 5
    elif x == 'negative':           
        return 6
    else:
        return x

# %%
df['Coombs_test'] = df['Coombs_test'].apply(lambda x: convert_Coombs_test(x))

# %%
df
# Out:
#        ID  age  sex  Retic_count  Bilirubin_count  LDH_count  Coombs_test  \
# 0       0   51    0         0.40             0.51      135.0         1000
# 1       1   15    1         0.08             0.22       23.0         1000
# 2       2   74    1         2.18             0.58       77.0         1000
# 3       3   66    0         0.38             0.60       25.0         1000
# 4       4   30    1         4.62             3.87      628.0            5
# ..    ...  ...  ...          ...              ...        ...          ...
# 976   995   38    0         1.91             0.27      127.0         1000
# 977   996   70    0         2.28             0.58      109.0         1000
# 978   997   41    1         0.42             0.77      120.0         1000
# 979   998   54    1         0.08             0.31       54.0         1000
# 980  1000   64    1         0.20             0.44      118.0         1000
#
#      Peripheral_Smear  Ferritin_level Hb_electrophoresis  \
# ...

# %%
def convert_Other_blood_cell_count(x):
    if x == 'normal_count':              
        return 15
    else:
        return 14

# %%
df['Other_blood_cell_count\(Pancytopenia +/-)'] = df['Other_blood_cell_count\(Pancytopenia +/-)'].apply(lambda x: convert_Other_blood_cell_count(x))

# %%
df
# Out:
#        ID  age  sex  Retic_count  Bilirubin_count  LDH_count  Coombs_test  \
# 0       0   51    0         0.40             0.51      135.0         1000
# 1       1   15    1         0.08             0.22       23.0         1000
# 2       2   74    1         2.18             0.58       77.0         1000
# 3       3   66    0         0.38             0.60       25.0         1000
# 4       4   30    1         4.62             3.87      628.0            5
# ..    ...  ...  ...          ...              ...        ...          ...
# 976   995   38    0         1.91             0.27      127.0         1000
# 977   996   70    0         2.28             0.58      109.0         1000
# 978   997   41    1         0.42             0.77      120.0         1000
# 979   998   54    1         0.08             0.31       54.0         1000
# 980  1000   64    1         0.20             0.44      118.0         1000
#
#      Peripheral_Smear  Ferritin_level Hb_electrophoresis  \
# ...

# %%
def convert_Hb_electrophoresis(x):
    if x == 'normal':              
        return 13
    elif x == 'HbA2,HbF +ve':
        return 12
    else:
        return x

# %%
df['Hb_electrophoresis'] = df['Hb_electrophoresis'].apply(lambda x: convert_Hb_electrophoresis(x))

# %%
df
# Out:
#        ID  age  sex  Retic_count  Bilirubin_count  LDH_count  Coombs_test  \
# 0       0   51    0         0.40             0.51      135.0         1000
# 1       1   15    1         0.08             0.22       23.0         1000
# 2       2   74    1         2.18             0.58       77.0         1000
# 3       3   66    0         0.38             0.60       25.0         1000
# 4       4   30    1         4.62             3.87      628.0            5
# ..    ...  ...  ...          ...              ...        ...          ...
# 976   995   38    0         1.91             0.27      127.0         1000
# 977   996   70    0         2.28             0.58      109.0         1000
# 978   997   41    1         0.42             0.77      120.0         1000
# 979   998   54    1         0.08             0.31       54.0         1000
# 980  1000   64    1         0.20             0.44      118.0         1000
#
#      Peripheral_Smear  Ferritin_level  Hb_electrophoresis  \
# ...

# %%
df['Serum_electrophoresis'].value_counts()
# Out:
# 1000        975
# MM-spike      6
# Name: Serum_electrophoresis, dtype: int64

# %%
def get_mm(x):
    if x == 'MM-spike':
        return 21
    else:
        return x

# %%
df['Serum_electrophoresis'] = df['Serum_electrophoresis'].apply(lambda x: get_mm(x))

# %%
df
# Out:
#        ID  age  sex  Retic_count  Bilirubin_count  LDH_count  Coombs_test  \
# 0       0   51    0         0.40             0.51      135.0         1000
# 1       1   15    1         0.08             0.22       23.0         1000
# 2       2   74    1         2.18             0.58       77.0         1000
# 3       3   66    0         0.38             0.60       25.0         1000
# 4       4   30    1         4.62             3.87      628.0            5
# ..    ...  ...  ...          ...              ...        ...          ...
# 976   995   38    0         1.91             0.27      127.0         1000
# 977   996   70    0         2.28             0.58      109.0         1000
# 978   997   41    1         0.42             0.77      120.0         1000
# 979   998   54    1         0.08             0.31       54.0         1000
# 980  1000   64    1         0.20             0.44      118.0         1000
#
#      Peripheral_Smear  Ferritin_level  Hb_electrophoresis  \
# ...
