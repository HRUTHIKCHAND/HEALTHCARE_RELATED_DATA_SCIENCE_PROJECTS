# %%
# import the modules
import pandas as pd
import numpy as np
import random

# %%
ID = list(np.linspace(0,1000,1000).astype(int))

# %%
age = np.random.normal(50, 15, 1000).astype(int).tolist()
age = [(x + 20) if x < 10 else x for x in age]

# %%
sex = []
for i in range(0,1000):
    x = random.randint(0, 1)
    sex.append(x)

# %%
Retic_count = []
for i in range(0,1000):
    x = random.randint(0, 2)
    Retic_count.append(x)

# %%
# create a DataFrame
Report = {'ID': ID,'age': age,'sex': sex,'Retic_count': Retic_count}
df = pd.DataFrame(Report)

# %%
df
# Out:
#        ID  age  sex  Retic_count
# 0       0   36    1            1
# 1       1   61    1            2
# 2       2   56    1            0
# 3       3   68    1            2
# 4       4   76    0            2
# ..    ...  ...  ...          ...
# 995   995   50    1            0
# 996   996   45    0            0
# 997   997   75    1            2
# 998   998   33    0            0
# 999  1000   36    1            1
#
# [1000 rows x 4 columns]

# %%
df['sex'].value_counts()
# Out:
# 1    501
# 0    499
# Name: sex, dtype: int64

# %%
df.insert(4,"Bilirubin_count",True)

# %%
def get_Bilirubin_count(x):
    if x == 0 or x == 1:
        return 0
    else :
        return random.randint(0 ,1)

# %%
# Set a length of the list to 1000
for i in range(0, 1000):
    df['Bilirubin_count'] = df['Retic_count'].apply(lambda x : get_Bilirubin_count(x))

# %%
df
# Out:
#        ID  age  sex  Retic_count  Bilirubin_count
# 0       0   36    1            1                0
# 1       1   61    1            2                0
# 2       2   56    1            0                0
# 3       3   68    1            2                0
# 4       4   76    0            2                0
# ..    ...  ...  ...          ...              ...
# 995   995   50    1            0                0
# 996   996   45    0            0                0
# 997   997   75    1            2                1
# 998   998   33    0            0                0
# 999  1000   36    1            1                0
#
# [1000 rows x 5 columns]

# %%
df['Bilirubin_count'].value_counts()
# Out:
# 0    842
# 1    158
# Name: Bilirubin_count, dtype: int64

# %%
df.insert(5,"LDH_count",True)

# %%
def get_LDH_count(x):
    if x == 0 :
        return 0
    else :
        return 1

# %%
df['LDH_count'] = df['Bilirubin_count'].apply(lambda x: get_LDH_count(x))

# %%
df
# Out:
#        ID  age  sex  Retic_count  Bilirubin_count  LDH_count
# 0       0   36    1            1                0          0
# 1       1   61    1            2                0          0
# 2       2   56    1            0                0          0
# 3       3   68    1            2                0          0
# 4       4   76    0            2                0          0
# ..    ...  ...  ...          ...              ...        ...
# 995   995   50    1            0                0          0
# 996   996   45    0            0                0          0
# 997   997   75    1            2                1          1
# 998   998   33    0            0                0          0
# 999  1000   36    1            1                0          0
#
# [1000 rows x 6 columns]

# %%
df['LDH_count'].value_counts()
# Out:
# 0    842
# 1    158
# Name: LDH_count, dtype: int64

# %%
df.insert(6,"Coombs'_test",True)

# %%
def get_Coombs_test(x):
    if x == 1:
        return random.randint(0,1)
    else:
        return 0

# %%
df["Coombs'_test"] = df['LDH_count'].apply(lambda x: get_Coombs_test(x))

# %%
df
# Out:
#        ID  age  sex  Retic_count  Bilirubin_count  LDH_count  Coombs'_test
# 0       0   36    1            1                0          0             0
# 1       1   61    1            2                0          0             0
# 2       2   56    1            0                0          0             0
# 3       3   68    1            2                0          0             0
# 4       4   76    0            2                0          0             0
# ..    ...  ...  ...          ...              ...        ...           ...
# 995   995   50    1            0                0          0             0
# 996   996   45    0            0                0          0             0
# 997   997   75    1            2                1          1             0
# 998   998   33    0            0                0          0             0
# 999  1000   36    1            1                0          0             0
#
# [1000 rows x 7 columns]

# %%
df["Coombs'_test"].value_counts()
# Out:
# 0    925
# 1     75
# Name: Coombs'_test, dtype: int64
