# %% [markdown]
# # <div style="display:fill;border-radius:5px;background-color:#676F9F;letter-spacing:0.5px;overflow:hidden"><p style="padding:20px;color:#F1EFF5;overflow:hidden;margin:0;font-size:150%;font-style: Helvetica;text-align:center"><b></b>WHAT IF DOCTOR🧑‍⚕️ PREPARES AN AI MODEL??🤔</p></div>

# %% [markdown]
# # <div style="display:fill;border-radius:5px;background-color:#676F9F;letter-spacing:0.5px;overflow:hidden"><p style="padding:20px;color:#F1EFF5;overflow:hidden;margin:0;font-size:110%;text-align:center"><b></b> PREDICTION_OF_LIVER_DISEASE_PROGNOSIS</p></div>

# %% [markdown]
# In this notebook, lets explore more about the dataset....

# %% [markdown]
# ## <font color='#4287f5'>1.Importing necessary libraries...</font>

# %%
import pandas as pd                       # library for data manipulation (data cleaning,analysing...)
import numpy as np                        # library for numerical computation
import matplotlib.pyplot as plt           # library for data visualization which is built on NumPy arrays
# %matplotlib inline 
import seaborn as sns                     # library for data visualization built on top of matplotlib and 
                                          # closely integrated with pandas data structures in Python.
import random

import warnings                           # to avoid warning flash 
warnings.filterwarnings('ignore')

# Other libraries will be imported in the following steps as the process moves . . . . .

# %% [markdown]
# ## <font color='#4287f5'>2.Loading the dataset....</font></center>

# %%
#Load the dataset which we have created previously......
df = pd.read_csv(r'D:\DSF\PROJECTPRO\MEDICAL_PROJECTS\7.PREDICTION_OF_LIVER_DISEASE_PROGNOSIS\cirrhosis.csv')

# %%
pd.set_option('display.max_rows', 500)
pd.set_option('display.max_columns', 500)

# %% [markdown]
# ## <font color='#4287f5'>Exploratory analysis of data...</font></center>

# %%
df
# Out:
#       ID  N_Days Status             Drug    Age Sex Ascites Hepatomegaly  \
# 0      1     400      D  D-penicillamine  21464   F       Y            Y
# 1      2    4500      C  D-penicillamine  20617   F       N            Y
# 2      3    1012      D  D-penicillamine  25594   M       N            N
# 3      4    1925      D  D-penicillamine  19994   F       N            Y
# 4      5    1504     CL          Placebo  13918   F       N            Y
# 5      6    2503      D          Placebo  24201   F       N            Y
# 6      7    1832      C          Placebo  20284   F       N            Y
# 7      8    2466      D          Placebo  19379   F       N            N
# 8      9    2400      D  D-penicillamine  15526   F       N            N
# 9     10      51      D          Placebo  25772   F       Y            N
# 10    11    3762      D          Placebo  19619   F       N            Y
# 11    12     304      D          Placebo  21600   F       N            N
# ...

# %% [markdown]
# #### Normal range:
#
# * S.Bilirubin: 0.1-1.0 mg/dl
# * S.Cholesterol: <200 mg/dl
# * S.Albumin: 3.5-5.5 g/dl
# * Urine Copper: <50 µg/day
# * S.Alkaline Phosphatase: 40-150 IU/L
# * SGOT : 8-45 U/L
# * S.Triglycerides: <150 mg/dl
# * Platelets : 150-400 cubic cells/L
# * Prothrombin time : 11-13.5 secs

# %% [markdown]
# #### Let see the range in our dataset

# %%
df_num_col = df.select_dtypes(include=(['int64', 'float64'])).columns
for c in df_num_col:
    print('range of',c,'is',df[c].min(),'-',df[c].max(),'\n')
# Out:
# range of ID is 1 - 418
#
# range of N_Days is 41 - 4795
#
# range of Age is 9598 - 28650
#
# range of Bilirubin is 0.3 - 28.0
#
# range of Cholesterol is 120.0 - 1775.0
#
# range of Albumin is 1.96 - 4.64
#
# range of Copper is 4.0 - 588.0
#
# range of Alk_Phos is 289.0 - 13862.4
#
# range of SGOT is 26.35 - 457.25
#
# range of Tryglicerides is 33.0 - 598.0
#
# range of Platelets is 62.0 - 721.0
#
# range of Prothrombin is 9.0 - 18.0
#
# range of Stage is 1.0 - 4.0

# %%
# Lets know the columns we are given with.....

df.columns
# Out:
# Index(['ID', 'N_Days', 'Status', 'Drug', 'Age', 'Sex', 'Ascites',
#        'Hepatomegaly', 'Spiders', 'Edema', 'Bilirubin', 'Cholesterol',
#        'Albumin', 'Copper', 'Alk_Phos', 'SGOT', 'Tryglicerides', 'Platelets',
#        'Prothrombin', 'Stage'],
#       dtype='object')

# %%
# Lets know the size of the dataframe we are working in....

df.shape
# Out:
# (418, 20)

# %%
# Lets get a basic summary of a DataFrame. 
# This method prints information about a DataFrame namely the index dtype and columns, non-null values and memory usage.

df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 418 entries, 0 to 417
# Data columns (total 20 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   ID             418 non-null    int64
#  1   N_Days         418 non-null    int64
#  2   Status         418 non-null    object
#  3   Drug           312 non-null    object
#  4   Age            418 non-null    int64
#  5   Sex            418 non-null    object
#  6   Ascites        312 non-null    object
#  7   Hepatomegaly   312 non-null    object
#  8   Spiders        312 non-null    object
#  9   Edema          418 non-null    object
#  10  Bilirubin      418 non-null    float64
#  11  Cholesterol    284 non-null    float64
#  12  Albumin        418 non-null    float64
#  13  Copper         310 non-null    float64
#  14  Alk_Phos       312 non-null    float64
#  15  SGOT           312 non-null    float64
#  16  Tryglicerides  282 non-null    float64
# ...

# %%
# This method describes how aur data is distributed....

df.describe()

# count: returns number of non-NA values
# mean : returns mean values of each feature(column)
# std  : returns values which indicates how much it is deviated from the mean
# min  : returns the minimum value of that feature column
# 25%  : returns the first 25% of the values in the respective feature
# 50%  : returns the first 50% of the values in the respective feature
# 75%  : returns the first 75% of the values in the respective feature
# max  : returns the maximum value of that feature column
# Out:
#                ID       N_Days           Age   Bilirubin  Cholesterol  \
# count  418.000000   418.000000    418.000000  418.000000   284.000000
# mean   209.500000  1917.782297  18533.351675    3.220813   369.510563
# std    120.810458  1104.672992   3815.845055    4.407506   231.944545
# min      1.000000    41.000000   9598.000000    0.300000   120.000000
# 25%    105.250000  1092.750000  15644.500000    0.800000   249.500000
# 50%    209.500000  1730.000000  18628.000000    1.400000   309.500000
# 75%    313.750000  2613.500000  21272.500000    3.400000   400.000000
# max    418.000000  4795.000000  28650.000000   28.000000  1775.000000
#
#           Albumin      Copper      Alk_Phos        SGOT  Tryglicerides  \
# count  418.000000  310.000000    312.000000  312.000000     282.000000
# mean     3.497440   97.648387   1982.655769  122.556346     124.702128
# std      0.424972   85.613920   2140.388824   56.699525      65.148639
# ...

# %%
df.describe(include='O')
# Out:
#        Status             Drug  Sex Ascites Hepatomegaly Spiders Edema
# count     418              312  418     312          312     312   418
# unique      3                2    2       2            2       2     3
# top         C  D-penicillamine    F       N            Y       N     N
# freq      232              158  374     288          160     222   354

# %% [markdown]
# As clear from the dataset info, there are so many missing values which can be seen in the above stats...

# %% [markdown]
# ## <font color='#4287f5'> Lets handle the missing values....</font>

# %%
# Lets count the numbers of missing values....

df.isnull().sum()
# Out:
# ID                 0
# N_Days             0
# Status             0
# Drug             106
# Age                0
# Sex                0
# Ascites          106
# Hepatomegaly     106
# Spiders          106
# Edema              0
# Bilirubin          0
# Cholesterol      134
# Albumin            0
# Copper           108
# Alk_Phos         106
# SGOT             106
# Tryglicerides    136
# Platelets         11
# Prothrombin        2
# Stage              6
# dtype: int64

# %% [markdown]
# * There are many methods to handle missing values including,
#     1. Discarding or removing any rows with missing values.
#     2. Fill missing values with either the mean/median/mode of the non-missing values.
#     3. Predicting the actual values using a separate machine learning model.

# %%
df1 = df.copy()

# %% [markdown]
# **" The dataset info says 112 cases did not participate in the clinical trial but consented to have basic measurements recorded and to be followed for survival. Six of those cases were lost to follow-up shortly after diagnosis. So, these 106 cases eventually have incomplete records,meaning missing records will be evident. As a doctor, I dont want to include these cases to be in the dataframe inorder to prepare an AI model. If any one tries to impute those missing values, it doesn't make sense medically. The act of doing to can be compared to a car which is fueled with adultered petrol or diesel. So,before moving on,lets delete those rows."**

# %% [markdown]
# The reason why I said so is that not even a doctor can not just simply say that the patient has hepatomegaly, splenomegaly, ascites or any such conditions by looking at other cases....

# %% [markdown]
# **Lets delete those 106 rows first.However, we can impute the Cholesterol and tryglycerides columns as they are continuous variables**

# %%
rows = df1.loc[pd.isna(df["Drug"]), :].index.tolist()

df1.drop(rows,axis=0,inplace=True)

# %%
df1.shape
# Out:
# (312, 20)

# %%
df1.isnull().sum()
# Out:
# ID                0
# N_Days            0
# Status            0
# Drug              0
# Age               0
# Sex               0
# Ascites           0
# Hepatomegaly      0
# Spiders           0
# Edema             0
# Bilirubin         0
# Cholesterol      28
# Albumin           0
# Copper            2
# Alk_Phos          0
# SGOT              0
# Tryglicerides    30
# Platelets         4
# Prothrombin       0
# Stage             0
# dtype: int64

# %%
df1['Cholesterol'].fillna(df1['Cholesterol'].mean(), inplace=True)

df1['Tryglicerides'].fillna(df1['Tryglicerides'].mean(), inplace=True)

df1['Copper'].fillna(df1['Copper'].mean(), inplace=True)

df1['Platelets'].fillna(df1['Platelets'].mean(), inplace=True)

# %%
df1.isnull().sum()
# Out:
# ID               0
# N_Days           0
# Status           0
# Drug             0
# Age              0
# Sex              0
# Ascites          0
# Hepatomegaly     0
# Spiders          0
# Edema            0
# Bilirubin        0
# Cholesterol      0
# Albumin          0
# Copper           0
# Alk_Phos         0
# SGOT             0
# Tryglicerides    0
# Platelets        0
# Prothrombin      0
# Stage            0
# dtype: int64

# %% [markdown]
# The features 'ID','N_Days','Age' are of no use for modelling AI as it does not provide any info. So,lets drop them.

# %%
df1.drop(['ID','N_Days','Age' ],axis=1,inplace=True)

# %% [markdown]
# **Now the data is clean and is ready for modelling...**

# %% [markdown]
# ## <font color='#4287f5'> Lets find the correlation between independant and dependant variables.....</font>

# %% [markdown]
# Which is the dependant variable in this dataset?  As I have told you before in the objective section that the feature 'Stage' refers to histologic stage of the disease which cannot be predicted even by the experienced Physician. Let see whether this is true....

# %%
df1.head(10)
# Out:
#   Status             Drug Sex Ascites Hepatomegaly Spiders Edema  Bilirubin  \
# 0      D  D-penicillamine   F       Y            Y       Y     Y       14.5
# 1      C  D-penicillamine   F       N            Y       Y     N        1.1
# 2      D  D-penicillamine   M       N            N       N     S        1.4
# 3      D  D-penicillamine   F       N            Y       Y     S        1.8
# 4     CL          Placebo   F       N            Y       Y     N        3.4
# 5      D          Placebo   F       N            Y       N     N        0.8
# 6      C          Placebo   F       N            Y       N     N        1.0
# 7      D          Placebo   F       N            N       N     N        0.3
# 8      D  D-penicillamine   F       N            N       Y     N        3.2
# 9      D          Placebo   F       Y            N       Y     Y       12.6
#
#    Cholesterol  Albumin  Copper  Alk_Phos    SGOT  Tryglicerides   Platelets  \
# ...

# %% [markdown]
# * Just look at the '0' row of the dataframe. In this case, there is presence of ascites,hepatomegaly,spiders,edema,increased bilirubin level,increased cholesterol level,hypoalbuminemia,increased urine copper level,increased ALP,SGOT. Almost every findings are abnormal and the Stage of the disease is labelled as '4'
# * Now,look at the 2nd row. Here,there is no presence of ascites,hepatomegaly,spiders,resolved edema,normal bilirubin, cholesterol, albumin, triglycerides, platelets. Yet again, the Stage of the disease is labelled as '4'.
# * What would be the reason for the same ? if you search these patterns in the whole dataset,you might find many examples of such cases...The answer is that the histologic(meaning study of cells/tissues by special stain) stage is not staged by looking at the blood levels of any chemicals..instead it is labelled by studying the presence of abnormal cells or altered cellular pattern or architecture.
# * So,if I, as a doctor, cannot predict the stage,then why should I model the AI to predict this? It doesn't make a sense

# %%
df1.Stage.value_counts()
# Out:
# 3.0    120
# 4.0    109
# 2.0     67
# 1.0     16
# Name: Stage, dtype: int64

# %% [markdown]
# So,there are 109 Severe cases. If it is severe, then invariably it indicates that complications like portal hypertension,hepatocellular failure will be present. If there is portal hypertension, then ascites,hepatomegaly would invariably be present. Lets check it...

# %%
df1[(df1.Ascites == 'Y') & (df1.Hepatomegaly == 'Y') & (df1.Stage == 4.0)].value_counts().sum()
# Out:
# 17

# %% [markdown]
# The results are shocking....only 17 cases have features like Ascites and hepatomegaly out of 109 severe cases. It doesn't make sense right?

# %%
# Lets visualize the same here...

sns.countplot(x ='Ascites', hue = "Stage", data = df1)
# Out:
# <AxesSubplot:xlabel='Ascites', ylabel='count'>

# %% [markdown]
# Now, lets check the presence of either of the features in severe disease...

# %%
df1[(df1.Ascites == 'Y') | (df1.Hepatomegaly == 'Y') & (df1.Stage == 4.0)].value_counts().sum()
# Out:
# 95

# %% [markdown]
# This slightly makes sense. Out of 109 severe cases, 95 cases have either ascites or hepatomegaly. But still, what about other 14 cases?

# %% [markdown]
# Now,lets see the presence of hypoalbuminemia. In severe form, serum albumin will be decreased. Hypoalbuminaemia is due to impairment of hepatic protein synthesis. Lets check the same.

# %%
# Lets check the cases with normal albumin level in the overall dataset...

df1[(df1.Albumin > 3.5)].value_counts().sum()
# Out:
# 172

# %%
# Lets check the cases with normal albumin level among the severe cases...

df1[(df1.Albumin >= 3.5) & (df1.Stage == 4.0)].value_counts().sum()
# Out:
# 39

# %% [markdown]
# **Out of 172 cases with normal S.Albumin level,39 cases are labelled to be severe.**

# %%
# Lets visualize the same...

plt.figure(figsize=(15,8))
sns.scatterplot(x=df.index,y=df.Albumin,hue=df.Stage)
plt.tick_params(axis='both', which='both', bottom=False, top=False, left=True)
plt.xlabel('')
plt.title('Scattered cases and labelled accordingly')
# Out:
# Text(0.5, 1.0, 'Scattered cases and labelled accordingly')

# %%
# Number of overall hypoalbuminemic cases

df1[(df1.Albumin <= 3.5)].value_counts().sum()
# Out:
# 140

# %%
# Number of  hypoalbuminemic cases labelled as Stage 4...

df1[(df1.Albumin <= 3.5)  & (df1.Stage == 4.0)].value_counts().sum()
# Out:
# 71

# %% [markdown]
# **Out of 140 hypoalbuminemic cases,only 71 cases are labelled as stage 4.**

# %% [markdown]
# So again, it does not make sense....But the remaining hypoalbuminemic cases might have been labelled as either of stage 1/2/3 which actually make sense. However, those who are labelled to be in stage 4 histologically, and if it is interpreted as severe form of the disease,then there must be presence of hypoalbuminemic cases.

# %% [markdown]
# ## <font color='#4287f5'> Lets make a new target variable.....</font>

# %% [markdown]
# Before that, lets know something called **"CHILD-PUGH CLASSIFICATION"**

# %% [markdown]
# **What is Child-Pugh classification in cirrhosis ?**
# *  The Child-Pugh (CP) scoring classification, originally devised to risk-stratify patients undergoing shunt surgery is useful to assess liver disease severity in patients with established cirrhosis
# * In cirrhosis, Child’s grade is used **to assess the hepato-cellular function**.
# * The determining 5 factors are :\
#     * serum bilirubin
#     * serum albumin
#     * ascites
#     * hepatic encephalopathy
#     * prothrombin time.
# * Every patient is assigned a class (A, B and C). **Class A is ’prognostically’ better** and **class C is the worst**. Child-Pugh scoring system (scores 5-15 encompassing class A, B, C) is used to assess prognosis and is a reliable predictor of survival.

# %% [markdown]
# <!DOCTYPE html>
# <html>
# <body>
#
# <h2 style= "text-align:center;color:#4287f5;font-size:120%;"><u> SEVERITY_ASSESSMENT </u></h2>
# <img src="CHILD_PUGH.png" alt="m" width="900" height="333">
#
# </body>
# </html>

# %% [markdown]
# Out of the above 5 features, we have 4 features in our dataset. We don't have the feature on encephalopathy. So, instead of that feature, we can include the 'Histologic_stage_feature' to classify the severity.Lets do it...

# %%
# Lets define functions to get points for the above 5 features mentioned....

def get_Ascites_point(x):
    if x == 'Y':
        return 3
    elif x == 'S':
        return 2
    else:
        return 1
                

def get_Albumin_point(x):
    if x <= 2.8:
        return 3
    elif (x > 2.8) & (x <= 3.5):
        return 2
    else:
        return 1

            
def get_Prothrombin_point(x):
    if x >= 6.0:
        return 3
    elif (x >= 4.0) & (x < 6.0):
        return 2
    else:
        return 1 


def get_Bilirubin_point(x):
    if x >= 3.0:
        return 3
    elif (x >= 2.0) & (x < 3.0):
        return 2
    else:
        return 1
            
def get_Stage_point(x):
    if x == 4.0:
        return 3
    elif (x == 2.0) | (x == 3.0):
        return 2
    else:
        return 1

# %%
# Lets get total points to assess severity score...
df1['Total_points'] = df1['Edema'].apply(lambda x: get_Ascites_point(x)) + df1['Albumin'].apply(lambda x: get_Albumin_point(x)) + df1['Prothrombin'].apply(lambda x: get_Prothrombin_point(x)) + df1['Bilirubin'].apply(lambda x:get_Bilirubin_point(x)) + df1['Stage'].apply(lambda x:get_Stage_point(x))

# %%
# Lets get the severity score which gives us prognosis similar to that of Child-Pugh score

def get_severity_score(x):
    if (x > 5) and (x <= 7):
        return 'CLASS A'
    elif (x > 8) and (x <= 10):
        return 'CLASS B'
    else:
        return 'CLASS C'

df1['Severity_class'] = df1['Total_points'].apply(lambda x: get_severity_score(x))

# %%
df1.head()
# Out:
#   Status             Drug Sex Ascites Hepatomegaly Spiders   Edema  Bilirubin  \
# 0      D  D-penicillamine   F       Y            Y       Y  Status       14.5
# 1      C  D-penicillamine   F       N            Y       Y  Status        1.1
# 2      D  D-penicillamine   M       N            N       N  Status        1.4
# 3      D  D-penicillamine   F       N            Y       Y  Status        1.8
# 4     CL          Placebo   F       N            Y       Y  Status        3.4
#
#    Cholesterol  Albumin  Copper  Alk_Phos    SGOT  Tryglicerides  Platelets  \
# 0        261.0     2.60   156.0    1718.0  137.95          172.0      190.0
# 1        302.0     4.14    54.0    7394.8  113.52           88.0      221.0
# 2        176.0     3.48   210.0     516.0   96.10           55.0      151.0
# 3        244.0     2.54    64.0    6121.8   60.63           92.0      183.0
# 4        279.0     3.53   143.0     671.0  113.15           72.0      136.0
#
# ...

# %%
df1['Severity_class'].value_counts()
# Out:
# CLASS C    179
# CLASS B    121
# CLASS A     12
# Name: Severity_class, dtype: int64

# %% [markdown]
# In this dataset, there are only 12 cases which have good prognosis,121 cases have moderate prognosis and 179 cases have poor prognosis...

# %% [markdown]
# ## Lets visualise the dataset in the next notebook....
