# %% [markdown]
# # <div style="display:fill;border-radius:5px;background-color:#676F9F;letter-spacing:0.5px;overflow:hidden"><p style="padding:20px;color:#F1EFF5;overflow:hidden;margin:0;font-size:150%;font-style: Helvetica;text-align:center"><b></b>WHAT IF DOCTOR🧑‍⚕️ PREPARES AN AI MODEL??🤔</p></div>

# %% [markdown]
# In the previous notebook, I focused on preparing a dataset which pretty much similar to the real world dataset on comparison.In this notebook, lets explore the dataset...

# %% [markdown]
# ## <font color='#4287f5'>Importing necessary libraries...</font>

# %%
import pandas as pd                       # library for data manipulation (data cleaning,analysing...)
import numpy as np                        # library for numerical computation
import matplotlib.pyplot as plt           # library for data visualization which is built on NumPy arrays
# %matplotlib inline
import seaborn as sns                     # library for data visualization built on top of matplotlib and 
                                          # closely integrated with pandas data structures in Python.

import random

import warnings                           # to avoid warning flash
warnings.filterwarnings('ignore')

# Other libraries will be imported in the following steps as the process moves....

# %%
df = pd.read_csv(r'D:\DSF\PROJECTPRO\MEDICAL_PROJECTS\5.BLOOD_REPORT_WRANGLING\all_reports.csv')

# %%
df
# Out:
#        ID  age  sex  Hb_level  RBC_count  MCV    HCT    MCH   MCHC   WBC  ...  \
# 0       0   25    0     11.39       4.62   79  36.50  24.65  31.21   3.4  ...
# 1       1   70    0      7.92       3.13   82  25.67  25.30  30.85  18.0  ...
# 2       2   49    0      9.21       4.39   81  35.56  20.98  25.90  15.7  ...
# 3       3   60    1     15.02       5.08   94  47.75  29.57  31.46   5.5  ...
# 4       4   37    1     12.48       4.79   77  36.88  26.05  33.84   4.7  ...
# ..    ...  ...  ...       ...        ...  ...    ...    ...    ...   ...  ...
# 995   995   63    0      8.54       3.06   84  25.70  27.91  33.23   9.8  ...
# 996   996   70    0     11.05       3.97   82  32.55  27.83  33.95  11.4  ...
# 997   997   57    0     13.35       4.08   86  35.09  32.72  38.05  10.3  ...
# 998   998   72    1     10.08       4.55   92  41.86  22.15  24.08  12.9  ...
# 999  1000   24    0      6.77       2.80   83  23.24  24.18  29.13   3.9  ...
#
# ...

# %%
df.head()
# Out:
#    ID  age  sex  Hb_level  RBC_count  MCV    HCT    MCH   MCHC   WBC  ...  \
# 0   0   25    0     11.39       4.62   79  36.50  24.65  31.21   3.4  ...
# 1   1   70    0      7.92       3.13   82  25.67  25.30  30.85  18.0  ...
# 2   2   49    0      9.21       4.39   81  35.56  20.98  25.90  15.7  ...
# 3   3   60    1     15.02       5.08   94  47.75  29.57  31.46   5.5  ...
# 4   4   37    1     12.48       4.79   77  36.88  26.05  33.84   4.7  ...
#
#     A1C  Conjugated_Bilirubin_count  Unconjugated_Bilirubin_count  \
# 0  7.00                        0.25                          0.06
# 1  6.56                        0.24                          0.20
# 2  7.11                        7.10                         10.02
# 3  7.11                        0.20                         10.83
# 4  7.63                        0.21                         11.31
#
#    Total_Bilirubin_count  Conjugated/Total_bilirubin_Ratio  urine_bile_salts  \
# ...

# %%
df.shape
# Out:
# (1000, 34)

# %%
df.columns
# Out:
# Index(['ID', 'age', 'sex', 'Hb_level', 'RBC_count', 'MCV', 'HCT', 'MCH',
#        'MCHC', 'WBC', 'Neutrophils', 'Lymphocytes', 'Monocytes', 'Eosinophils',
#        'Basophils', 'Platelet_count', 'Sodium_level', 'Potassium_level',
#        'Chloride_level', 'Bicarbonate_level', 'Blood_urea_level',
#        'Serum_creatinine_level', 'FPG', 'OGTT', 'A1C',
#        'Conjugated_Bilirubin_count', 'Unconjugated_Bilirubin_count',
#        'Total_Bilirubin_count', 'Conjugated/Total_bilirubin_Ratio',
#        'urine_bile_salts', 'AST', 'ALT', 'ALP', 'Serum_albumin'],
#       dtype='object')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 34 columns):
#  #   Column                            Non-Null Count  Dtype
# ---  ------                            --------------  -----
#  0   ID                                1000 non-null   int64
#  1   age                               1000 non-null   int64
#  2   sex                               1000 non-null   int64
#  3   Hb_level                          1000 non-null   float64
#  4   RBC_count                         1000 non-null   float64
#  5   MCV                               1000 non-null   int64
#  6   HCT                               1000 non-null   float64
#  7   MCH                               1000 non-null   float64
#  8   MCHC                              1000 non-null   float64
#  9   WBC                               1000 non-null   float64
#  10  Neutrophils                       1000 non-null   float64
# ...

# %% [markdown]
# All of the features are either in integer or float datatype...

# %%
df.describe()
# Out:
#                 ID          age          sex     Hb_level    RBC_count  \
# count  1000.000000  1000.000000  1000.000000  1000.000000  1000.000000
# mean    499.501000    49.393000     0.514000     9.306400     3.583600
# std     288.821169    14.571921     0.500054     4.207862     1.010682
# min       0.000000     9.000000     0.000000     2.030000     1.800000
# 25%     249.750000    39.000000     0.000000     5.917500     2.710000
# 50%     499.500000    49.000000     1.000000     9.200000     3.665000
# 75%     749.250000    60.000000     1.000000    13.312500     4.492500
# max    1000.000000   102.000000     1.000000    15.990000     5.490000
#
#                MCV          HCT          MCH         MCHC          WBC  ...  \
# count  1000.000000  1000.000000  1000.000000  1000.000000  1000.000000  ...
# mean     82.525000    30.114110    24.976910    30.098630    11.009300  ...
# std       8.471667    10.518903     7.186719     7.698719     4.623858  ...
# ...

# %%
df.isnull().sum()
# Out:
# ID                                  0
# age                                 0
# sex                                 0
# Hb_level                            0
# RBC_count                           0
# MCV                                 0
# HCT                                 0
# MCH                                 0
# MCHC                                0
# WBC                                 0
# Neutrophils                         0
# Lymphocytes                         0
# Monocytes                           0
# Eosinophils                         0
# Basophils                           0
# Platelet_count                      0
# Sodium_level                        0
# Potassium_level                     0
# Chloride_level                      0
# Bicarbonate_level                   0
# Blood_urea_level                    0
# Serum_creatinine_level              0
# FPG                                 0
# OGTT                                0
# A1C                                 0
# ...

# %% [markdown]
# Since the dataset is hand made, there are no missing values but in real world, the dataset usually will be filled with more number of missing values. Don't be too happy, the real world dataset is not so pure as we have here. Most of the datasets contain more number of data bugs than being the pure one which I have here.

# %%
pd.set_option('display.max_columns',500)
pd.set_option('display.max_rows',500)

# %% [markdown]
# ### What is the target variable in this dataset?

# %% [markdown]
# The target variable is not yet inserted yet to the dataset !!!
# In this dataset, I would like to insert as many target variables as possible so that I can prepare many AI models out of it....

# %%
# first target variable -- 'Anemic_status'

# %%
df.insert(4,'Anemic_status',True)

# %%
def get_Anemic_status(x):
    if x >= 12.5:
        return 0       # normal
    elif x >= 9 and x < 12.5:
        return 1       # mild anaemia
    elif x >= 6 and x < 9:
        return 2       # moderate anaemia
    else:
        return 3       # severe anaemia

# %%
df['Anemic_status'] = df['Hb_level'].apply(lambda x: get_Anemic_status(x))

# %%
df
# Out:
#        ID  age  sex  Hb_level  Anemic_status  RBC_count  MCV    HCT    MCH  \
# 0       0   25    0     11.39              1       4.62   79  36.50  24.65
# 1       1   70    0      7.92              2       3.13   82  25.67  25.30
# 2       2   49    0      9.21              1       4.39   81  35.56  20.98
# 3       3   60    1     15.02              0       5.08   94  47.75  29.57
# 4       4   37    1     12.48              1       4.79   77  36.88  26.05
# ..    ...  ...  ...       ...            ...        ...  ...    ...    ...
# 995   995   63    0      8.54              2       3.06   84  25.70  27.91
# 996   996   70    0     11.05              1       3.97   82  32.55  27.83
# 997   997   57    0     13.35              0       4.08   86  35.09  32.72
# 998   998   72    1     10.08              1       4.55   92  41.86  22.15
# 999  1000   24    0      6.77              2       2.80   83  23.24  24.18
#
# ...

# %%
df.insert(5,'managing_anemia',True)

# %%
def get_managing_anemia(x):
    if x == 0:
        return 0                         # 0 - continue healthy lifestyle with balanced diet, moderate exercise and good sleep
    elif x == 1:
        return 1                         # 1 - mild anemia can be managed conservatively by prescribing iron rich foods or oral tabs
    elif x == 2:
        return 2                         # 2 - oral tabs + Inj, evaluate for the cause and treat it...
    else:
        return 3                         # 3 - Hospitalization and blood transfusion,evaluate for the cause and treat it..

# %%
df['managing_anemia'] = df['Anemic_status'].apply(lambda x: get_managing_anemia(x))

# %%
df
# Out:
#        ID  age  sex  Hb_level  Anemic_status  managing_anemia  RBC_count  MCV  \
# 0       0   25    0     11.39              1                1       4.62   79
# 1       1   70    0      7.92              2                2       3.13   82
# 2       2   49    0      9.21              1                1       4.39   81
# 3       3   60    1     15.02              0                0       5.08   94
# 4       4   37    1     12.48              1                1       4.79   77
# ..    ...  ...  ...       ...            ...              ...        ...  ...
# 995   995   63    0      8.54              2                2       3.06   84
# 996   996   70    0     11.05              1                1       3.97   82
# 997   997   57    0     13.35              0                0       4.08   86
# 998   998   72    1     10.08              1                1       4.55   92
# 999  1000   24    0      6.77              2                2       2.80   83
#
# ...

# %%
# 2nd target variable -- 'infection_status'

# %%
df.insert(17,'infection_status',True)

# %%
def get_infection_status(x):
    if x < 4:
        return 0                        # leucocytopenia
    elif x >= 4 and x < 11:
        return 1                        # normal
    else:
        return 2                        # Leucocytosis

# %%
df['infection_status'] = df['WBC'].apply(lambda x: get_infection_status(x))

# %%
df.insert(18,'managing_infection',True)

# %%
def how_to_manage_infection(x):
    if x == 0:
        return 0        # 0 - evaluate for the low wbc count i.e low immunity, check for HIV,DM or other immunocompromised state
    elif x == 1:
        return 1        # 1 - normal, nothing to worry
    else:
        return 2        # 2 - '!!!there is infection',find the foci of infection and treat the cause with suitable antibiotics

# %%
df['managing_infection'] = df['infection_status'].apply(lambda x: how_to_manage_infection(x))

# %%
df
# Out:
#        ID  age  sex  Hb_level  Anemic_status  managing_anemia  RBC_count  MCV  \
# 0       0   25    0     11.39              1                1       4.62   79
# 1       1   70    0      7.92              2                2       3.13   82
# 2       2   49    0      9.21              1                1       4.39   81
# 3       3   60    1     15.02              0                0       5.08   94
# 4       4   37    1     12.48              1                1       4.79   77
# ..    ...  ...  ...       ...            ...              ...        ...  ...
# 995   995   63    0      8.54              2                2       3.06   84
# 996   996   70    0     11.05              1                1       3.97   82
# 997   997   57    0     13.35              0                0       4.08   86
# 998   998   72    1     10.08              1                1       4.55   92
# 999  1000   24    0      6.77              2                2       2.80   83
#
# ...

# %%
# 3rd target variable -- 'Bleeding_status'

# %%
df.insert(20,'Bleeding_status',True)

# %%
conditions = [
    df['Platelet_count'] < 1.5,
    (df['Platelet_count'] >= 1.5) & (df['Platelet_count'] < 5 ),
    df['Platelet_count'] >= 5
]

choices = [0,1,2]         # 0- Thrombocytopenia     1-normal     2-thrombocytosis

df['Bleeding_status'] = np.select(conditions, choices, default=0)

# %%
df.insert(21,'managing_platelet_disorders',True)

# %%
#now manage platelet disorders......
def how_to_manage_platelet_disorder(x):
    if x == 0:       # Thrombocytopenia
        return 0     # evaluate for the cause and if critical, transfuse platelet precipitates or FFP's
    elif x == 1:
        return 1     # normal......nothing to worry
    else:
        return 2     # Thrombocytosis, evaluate for the cause and treat it ....

# %%
df['managing_platelet_disorders'] = df['Bleeding_status'].apply(lambda x: how_to_manage_platelet_disorder(x))

# %%
df
# Out:
#        ID  age  sex  Hb_level  Anemic_status  managing_anemia  RBC_count  MCV  \
# 0       0   25    0     11.39              1                1       4.62   79
# 1       1   70    0      7.92              2                2       3.13   82
# 2       2   49    0      9.21              1                1       4.39   81
# 3       3   60    1     15.02              0                0       5.08   94
# 4       4   37    1     12.48              1                1       4.79   77
# ..    ...  ...  ...       ...            ...              ...        ...  ...
# 995   995   63    0      8.54              2                2       3.06   84
# 996   996   70    0     11.05              1                1       3.97   82
# 997   997   57    0     13.35              0                0       4.08   86
# 998   998   72    1     10.08              1                1       4.55   92
# 999  1000   24    0      6.77              2                2       2.80   83
#
# ...

# %%
# 4th target variable

df.insert(23,'Sodium_level_status',True)

def get_Sodium_level_status(x):
    if x < 125:
        return 0        # hyponatraemia(correction needed)
    elif x >145:
        return 2        # hypernatraemia (correction needed)
    else:
        return 1        # normal
    
df['Sodium_level_status'] = df['Sodium_level'].apply(lambda x:get_Sodium_level_status(x))

# %%
# 5th target variable

df.insert(25,'Potassium_level_status',True)

def get_Potassium_level_status(x):
    if x < 3.5:
        return 0        # hypokalaemia(correction needed)
    elif x >5:
        return 2        # hyperkalaemia (correction needed)
    else:
        return 1        # normal
    
df['Potassium_level_status'] = df['Potassium_level'].apply(lambda x: get_Potassium_level_status(x))

# %%
# 6th target variable

df.insert(27,'Chloride_level_status',True)

def get_Chloride_level_status(x):
    if x < 96:
        return 0        # hypochloraemia(correction needed)
    elif x >106:
        return 2        # hyperchloraemia (correction needed)
    else:
        return 1        # normal
    
df['Chloride_level_status'] = df['Chloride_level'].apply(lambda x:get_Chloride_level_status(x))

# %%
# 7th target variable

df.insert(29,'Bicarbonate_level_status',True)

def get_Bicarbonate_level_status(x):
    if x < 96:
        return 0        # hypochloraemia(correction needed)
    elif x >106:
        return 2        # hyperchloraemia (correction needed)
    else:
        return 1        # normal
    
df['Bicarbonate_level_status'] = df['Bicarbonate_level'].apply(lambda x:get_Bicarbonate_level_status(x))

# %%
df
# Out:
#        ID  age  sex  Hb_level  Anemic_status  managing_anemia  RBC_count  MCV  \
# 0       0   25    0     11.39              1                1       4.62   79
# 1       1   70    0      7.92              2                2       3.13   82
# 2       2   49    0      9.21              1                1       4.39   81
# 3       3   60    1     15.02              0                0       5.08   94
# 4       4   37    1     12.48              1                1       4.79   77
# ..    ...  ...  ...       ...            ...              ...        ...  ...
# 995   995   63    0      8.54              2                2       3.06   84
# 996   996   70    0     11.05              1                1       3.97   82
# 997   997   57    0     13.35              0                0       4.08   86
# 998   998   72    1     10.08              1                1       4.55   92
# 999  1000   24    0      6.77              2                2       2.80   83
#
# ...

# %%
# 8th target variable

df.insert(32,'kidney_status',True)

def get_kidney_status(x):
    if x > 2:
        return 1        # unhealthy (high S.Creat level indicates kidney pathology which may be either acute or chronic)
    else:
        return 0        # healthy status

df['kidney_status'] = df['Serum_creatinine_level'].apply(lambda x: get_kidney_status(x))

# %%
# 9th target variable

df.insert(36,"Diabetic_status",True)

def get_Diabetic_status(x):
    if x > 6.5:                  # if the HbA1c values > 6.5 , then Diabetic
        return 2
    elif x > 5.7 and x < 6.5:    # if the HbA1c values between 5.7 and 6.5 , then Pre-Diabetic
        return 1
    else :                       # # if the HbA1c values < 5.7 , then normal.
        return 0
    
# Set a length of the list to 1000
for i in range(0, 1000):
    df['Diabetic_status'] = df['A1C'].apply(lambda x: get_Diabetic_status(x))

# %%
# 10th target variable

df.insert(45,"LFT_status",True)

# 0 ---> Normal
# 1 ---> Jaundice

def get_LFT_status(x):
    if x > 0 and x < 1:                 
        return 0
    else :                       
        return 1

df['LFT_status'] = df['Total_Bilirubin_count'].apply(lambda x: get_LFT_status(x))

# %%
df
# Out:
#        ID  age  sex  Hb_level  Anemic_status  managing_anemia  RBC_count  MCV  \
# 0       0   25    0     11.39              1                1       4.62   79
# 1       1   70    0      7.92              2                2       3.13   82
# 2       2   49    0      9.21              1                1       4.39   81
# 3       3   60    1     15.02              0                0       5.08   94
# 4       4   37    1     12.48              1                1       4.79   77
# ..    ...  ...  ...       ...            ...              ...        ...  ...
# 995   995   63    0      8.54              2                2       3.06   84
# 996   996   70    0     11.05              1                1       3.97   82
# 997   997   57    0     13.35              0                0       4.08   86
# 998   998   72    1     10.08              1                1       4.55   92
# 999  1000   24    0      6.77              2                2       2.80   83
#
# ...

# %% [markdown]
# There are still many more target variables which can be added but as this project is for intuition purpose, let me stop and build the AI models from here on...

# %% [markdown]
# Its just not getting the status of specific tests but we can also get immediate operating protocol for the specific abnormalities....Lets see on the next notebook...
