# %% [markdown]
# # <div style="display:fill;border-radius:5px;background-color:#676F9F;letter-spacing:0.5px;overflow:hidden"><p style="padding:20px;color:#F1EFF5;overflow:hidden;margin:0;font-size:150%;font-style: Helvetica;text-align:center"><b></b>WHAT IF DOCTOR🧑‍⚕️ PREPARES AN AI MODEL??🤔</p></div>

# %% [markdown]
# # <div style="display:fill;border-radius:5px;background-color:#676F9F;letter-spacing:0.5px;overflow:hidden"><p style="padding:20px;color:#F1EFF5;overflow:hidden;margin:0;font-size:110%;text-align:center"><b></b>CREATING_THE_DATASET </p></div>

# %% [markdown]
# ## <font color='#4287f5'>Importing necessary libraries...</font>

# %%
import pandas as pd                       # library for data manipulation (data cleaning,analysing...)
import numpy as np                        # library for numerical computation
import matplotlib.pyplot as plt           # library for data visualization which is built on NumPy arrays
# %matplotlib inline
import seaborn as sns                     # library for data visualization built on top of matplotlib and 
                                          # closely integrated with pandas data structures in Python.

import random

import warnings                           # to avoid warning flash
warnings.filterwarnings('ignore')

# Other libraries will be imported in the following steps as the process moves....

# %%
ID = list(np.linspace(0,1000,1000).astype(int))

# %%
age = np.random.normal(50, 15, 1000).astype(int).tolist()
age = [(x + 20) if x < 10 else x for x in age]

# %%
sex = []
for i in range(0,1000):
    x = random.randint(0, 1)               # 0 - female    1 - male
    sex.append(x)

# %%
Anemic_status = []
for i in range(0,1000):
    x = random.randint(0, 3)
    Anemic_status.append(x)

# %%
# create a DataFrame
Report = {'ID': ID,'age': age,'sex': sex,'Anemic_status': Anemic_status}
df = pd.DataFrame(Report)

# %%
df
# Out:
#        ID  age  sex  Anemic_status
# 0       0   57    1              1
# 1       1   76    1              2
# 2       2   65    0              3
# 3       3   36    0              3
# 4       4   63    0              0
# ..    ...  ...  ...            ...
# 995   995   21    1              3
# 996   996   72    1              0
# 997   997   74    0              3
# 998   998   64    1              2
# 999  1000   45    0              0
#
# [1000 rows x 4 columns]

# %%
df['Anemic_status'].value_counts()               # 0 - Normal    1 - Mild    2 - Moderate  3 - Severe
# Out:
# 0    286
# 2    253
# 3    238
# 1    223
# Name: Anemic_status, dtype: int64

# %%
df.insert(4,'Hb_level',True)

# %%
def get_Hb_level(x):
    if x == 0:
        return round(random.uniform(13,16),2)
    elif x == 1:
        return round(random.uniform(9,13),2)
    elif x == 2:
        return round(random.uniform(6,9),2)
    else:
        return round(random.uniform(2,6),2)

# %%
df['Hb_level'] = df['Anemic_status'].apply(lambda x: get_Hb_level(x))

# %%
df
# Out:
#        ID  age  sex  Anemic_status  Hb_level
# 0       0   57    1              1     11.49
# 1       1   76    1              2      6.02
# 2       2   65    0              3      4.14
# 3       3   36    0              3      5.46
# 4       4   63    0              0     13.56
# ..    ...  ...  ...            ...       ...
# 995   995   21    1              3      2.21
# 996   996   72    1              0     15.73
# 997   997   74    0              3      4.12
# 998   998   64    1              2      7.18
# 999  1000   45    0              0     15.30
#
# [1000 rows x 5 columns]

# %%
df.insert(5,'managing_anemia',True)

# %%
def get_managing_anemia(x):
    if x == 0:
        return 0                         # 0 - continue healthy lifestyle with balanced diet, moderate exercise and good sleep
    elif x == 1:
        return 1                         # 1 - mild anemia can be managed conservatively by prescribing iron rich foods or oral tabs
    elif x == 2:
        return 2                         # 2 - oral tabs + Inj, evaluate for the cause and treat it...
    else:
        return 3                         # 3 - Hospitalization and blood transfusion,evaluate for the cause and treat it..

# %%
df['managing_anemia'] = df['Anemic_status'].apply(lambda x: get_managing_anemia(x))

# %%
df
# Out:
#        ID  age  sex  Anemic_status  Hb_level  managing_anemia
# 0       0   57    1              1     11.49                1
# 1       1   76    1              2      6.02                2
# 2       2   65    0              3      4.14                3
# 3       3   36    0              3      5.46                3
# 4       4   63    0              0     13.56                0
# ..    ...  ...  ...            ...       ...              ...
# 995   995   21    1              3      2.21                3
# 996   996   72    1              0     15.73                0
# 997   997   74    0              3      4.12                3
# 998   998   64    1              2      7.18                2
# 999  1000   45    0              0     15.30                0
#
# [1000 rows x 6 columns]

# %%
df.insert(6,'RBC_count',True)

# %%
# RBC_count in (value x 10^12/L)
def f(x):
    if x['sex'] == 0 and x['Anemic_status'] == 0:
        return round(random.uniform(3.5,5.0),2)
    elif x['sex'] == 0 and x['Anemic_status'] == 1:
        return round(random.uniform(3.2,4.8),2)
    elif x['sex'] == 0 and x['Anemic_status'] == 2:
        return round(random.uniform(2.5,3.2),2)
    elif x['sex'] == 0 and x['Anemic_status'] == 3:
        return round(random.uniform(1.8,2.5),2)
    elif x['sex'] == 1 and x['Anemic_status'] == 0:
        return round(random.uniform(4.5,5.5),2)
    elif x['sex'] == 1 and x['Anemic_status'] == 1:
        return round(random.uniform(4.0,4.8),2)
    elif x['sex'] == 1 and x['Anemic_status'] == 2:
        return round(random.uniform(3.0,4.0),2)
    else:
        return round(random.uniform(2.0,3.0),2)

# %%
df['RBC_count'] = df.apply(f, axis=1)

# %%
df
# Out:
#        ID  age  sex  Anemic_status  Hb_level  managing_anemia  RBC_count
# 0       0   57    1              1     11.49                1       4.49
# 1       1   76    1              2      6.02                2       3.20
# 2       2   65    0              3      4.14                3       2.45
# 3       3   36    0              3      5.46                3       2.13
# 4       4   63    0              0     13.56                0       4.96
# ..    ...  ...  ...            ...       ...              ...        ...
# 995   995   21    1              3      2.21                3       2.24
# 996   996   72    1              0     15.73                0       5.07
# 997   997   74    0              3      4.12                3       1.81
# 998   998   64    1              2      7.18                2       3.19
# 999  1000   45    0              0     15.30                0       4.66
#
# [1000 rows x 7 columns]

# %%
df[(df['sex'] == 0) & (df['Anemic_status'] == 0)].value_counts().sum()
# Out:
# 136

# %%
df[df['RBC_count'] > 4].value_counts().sum()
# Out:
# 403

# %%
df.insert(7,'MCV',True)

# %%
# MCV in fL
def get_MCV(x):
    if x == 0:
        return random.randint(80,100)
    elif x == 1:
        return random.randint(75,95)
    elif x == 2:
        return random.randint(70,90)
    else:
        return random.randint(65,85)

# %%
df['MCV'] = df['Anemic_status'].apply(lambda x: get_MCV(x))

# %%
df
# Out:
#        ID  age  sex  Anemic_status  Hb_level  managing_anemia  RBC_count  MCV
# 0       0   57    1              1     11.49                1       4.49   79
# 1       1   76    1              2      6.02                2       3.20   88
# 2       2   65    0              3      4.14                3       2.45   75
# 3       3   36    0              3      5.46                3       2.13   83
# 4       4   63    0              0     13.56                0       4.96  100
# ..    ...  ...  ...            ...       ...              ...        ...  ...
# 995   995   21    1              3      2.21                3       2.24   81
# 996   996   72    1              0     15.73                0       5.07   96
# 997   997   74    0              3      4.12                3       1.81   70
# 998   998   64    1              2      7.18                2       3.19   77
# 999  1000   45    0              0     15.30                0       4.66   82
#
# [1000 rows x 8 columns]

# %%
df.insert(8,'HCT',True)

# %%
df['HCT'] = (df['RBC_count'].multiply(df['MCV']))/10

# %%
df['HCT'] = round(df['HCT'],2)

# %%
df
# Out:
#        ID  age  sex  Anemic_status  Hb_level  managing_anemia  RBC_count  MCV  \
# 0       0   57    1              1     11.49                1       4.49   79
# 1       1   76    1              2      6.02                2       3.20   88
# 2       2   65    0              3      4.14                3       2.45   75
# 3       3   36    0              3      5.46                3       2.13   83
# 4       4   63    0              0     13.56                0       4.96  100
# ..    ...  ...  ...            ...       ...              ...        ...  ...
# 995   995   21    1              3      2.21                3       2.24   81
# 996   996   72    1              0     15.73                0       5.07   96
# 997   997   74    0              3      4.12                3       1.81   70
# 998   998   64    1              2      7.18                2       3.19   77
# 999  1000   45    0              0     15.30                0       4.66   82
#
#        HCT
# 0    35.47
# ...

# %%
df[df['HCT'] > 50].value_counts().sum()
# Out:
# 21

# %%
df['HCT'].min()
# Out:
# 12.66

# %%
df.insert(9,'MCH',True)

# %%
df['MCH'] = (df['Hb_level'].multiply(10))/df['RBC_count']

# %%
df['MCH'] = round(df['MCH'],2)               # normal range : 26-36pg

# %%
df
# Out:
#        ID  age  sex  Anemic_status  Hb_level  managing_anemia  RBC_count  MCV  \
# 0       0   57    1              1     11.49                1       4.49   79
# 1       1   76    1              2      6.02                2       3.20   88
# 2       2   65    0              3      4.14                3       2.45   75
# 3       3   36    0              3      5.46                3       2.13   83
# 4       4   63    0              0     13.56                0       4.96  100
# ..    ...  ...  ...            ...       ...              ...        ...  ...
# 995   995   21    1              3      2.21                3       2.24   81
# 996   996   72    1              0     15.73                0       5.07   96
# 997   997   74    0              3      4.12                3       1.81   70
# 998   998   64    1              2      7.18                2       3.19   77
# 999  1000   45    0              0     15.30                0       4.66   82
#
#        HCT    MCH
# ...

# %%
df.insert(10,'MCHC',True)

# %%
df['MCHC'] = (df['Hb_level'].multiply(100))/df['HCT']

# %%
df['MCHC'] = round(df['MCHC'],2)               # normal range : 30-36%

# %%
df
# Out:
#        ID  age  sex  Anemic_status  Hb_level  managing_anemia  RBC_count  MCV  \
# 0       0   57    1              1     11.49                1       4.49   79
# 1       1   76    1              2      6.02                2       3.20   88
# 2       2   65    0              3      4.14                3       2.45   75
# 3       3   36    0              3      5.46                3       2.13   83
# 4       4   63    0              0     13.56                0       4.96  100
# ..    ...  ...  ...            ...       ...              ...        ...  ...
# 995   995   21    1              3      2.21                3       2.24   81
# 996   996   72    1              0     15.73                0       5.07   96
# 997   997   74    0              3      4.12                3       1.81   70
# 998   998   64    1              2      7.18                2       3.19   77
# 999  1000   45    0              0     15.30                0       4.66   82
#
#        HCT    MCH   MCHC
# ...

# %%
df.insert(11,'WBC',True)

# %%
def get_WBC(x):
    return round(random.uniform(3,19),1)

# %%
df['WBC'] = df['WBC'].apply(lambda x: get_WBC(x))

# %%
df
# Out:
#        ID  age  sex  Anemic_status  Hb_level  managing_anemia  RBC_count  MCV  \
# 0       0   57    1              1     11.49                1       4.49   79
# 1       1   76    1              2      6.02                2       3.20   88
# 2       2   65    0              3      4.14                3       2.45   75
# 3       3   36    0              3      5.46                3       2.13   83
# 4       4   63    0              0     13.56                0       4.96  100
# ..    ...  ...  ...            ...       ...              ...        ...  ...
# 995   995   21    1              3      2.21                3       2.24   81
# 996   996   72    1              0     15.73                0       5.07   96
# 997   997   74    0              3      4.12                3       1.81   70
# 998   998   64    1              2      7.18                2       3.19   77
# 999  1000   45    0              0     15.30                0       4.66   82
#
#        HCT    MCH   MCHC   WBC
# ...

# %%
df['Neutrophils'] = (df['WBC'].multiply(round(random.uniform(50,70),2))/100)

# %%
df['Neutrophils'] = round(df['Neutrophils'],2)

# %%
df
# Out:
#        ID  age  sex  Anemic_status  Hb_level  managing_anemia  RBC_count  MCV  \
# 0       0   57    1              1     11.49                1       4.49   79
# 1       1   76    1              2      6.02                2       3.20   88
# 2       2   65    0              3      4.14                3       2.45   75
# 3       3   36    0              3      5.46                3       2.13   83
# 4       4   63    0              0     13.56                0       4.96  100
# ..    ...  ...  ...            ...       ...              ...        ...  ...
# 995   995   21    1              3      2.21                3       2.24   81
# 996   996   72    1              0     15.73                0       5.07   96
# 997   997   74    0              3      4.12                3       1.81   70
# 998   998   64    1              2      7.18                2       3.19   77
# 999  1000   45    0              0     15.30                0       4.66   82
#
# ...

# %%
df['Lymphocytes'] = (df['WBC'].multiply(round(random.uniform(20,40),2))/100)

# %%
df['Lymphocytes'] = round(df['Lymphocytes'],2)

# %%
df
# Out:
#        ID  age  sex  Anemic_status  Hb_level  managing_anemia  RBC_count  MCV  \
# 0       0   57    1              1     11.49                1       4.49   79
# 1       1   76    1              2      6.02                2       3.20   88
# 2       2   65    0              3      4.14                3       2.45   75
# 3       3   36    0              3      5.46                3       2.13   83
# 4       4   63    0              0     13.56                0       4.96  100
# ..    ...  ...  ...            ...       ...              ...        ...  ...
# 995   995   21    1              3      2.21                3       2.24   81
# 996   996   72    1              0     15.73                0       5.07   96
# 997   997   74    0              3      4.12                3       1.81   70
# 998   998   64    1              2      7.18                2       3.19   77
# 999  1000   45    0              0     15.30                0       4.66   82
#
# ...

# %%
df['Monocytes'] = (df['WBC'].multiply(round(random.uniform(5,10),2))/100)

# %%
df['Monocytes'] = round(df['Monocytes'],2)

# %%
df
# Out:
#        ID  age  sex  Anemic_status  Hb_level  managing_anemia  RBC_count  MCV  \
# 0       0   57    1              1     11.49                1       4.49   79
# 1       1   76    1              2      6.02                2       3.20   88
# 2       2   65    0              3      4.14                3       2.45   75
# 3       3   36    0              3      5.46                3       2.13   83
# 4       4   63    0              0     13.56                0       4.96  100
# ..    ...  ...  ...            ...       ...              ...        ...  ...
# 995   995   21    1              3      2.21                3       2.24   81
# 996   996   72    1              0     15.73                0       5.07   96
# 997   997   74    0              3      4.12                3       1.81   70
# 998   998   64    1              2      7.18                2       3.19   77
# 999  1000   45    0              0     15.30                0       4.66   82
#
# ...

# %%
df['Eosinophils'] = (df['WBC'].multiply(round(random.uniform(0,2),2))/100)

# %%
df['Eosinophils'] = round(df['Eosinophils'],2)

# %%
df
# Out:
#        ID  age  sex  Anemic_status  Hb_level  managing_anemia  RBC_count  MCV  \
# 0       0   57    1              1     11.49                1       4.49   79
# 1       1   76    1              2      6.02                2       3.20   88
# 2       2   65    0              3      4.14                3       2.45   75
# 3       3   36    0              3      5.46                3       2.13   83
# 4       4   63    0              0     13.56                0       4.96  100
# ..    ...  ...  ...            ...       ...              ...        ...  ...
# 995   995   21    1              3      2.21                3       2.24   81
# 996   996   72    1              0     15.73                0       5.07   96
# 997   997   74    0              3      4.12                3       1.81   70
# 998   998   64    1              2      7.18                2       3.19   77
# 999  1000   45    0              0     15.30                0       4.66   82
#
# ...

# %%
df['Basophils'] = (df['WBC'].multiply(round(random.uniform(2,4),2))/100)

# %%
df['Basophils'] = round(df['Basophils'] ,2)

# %%
df
# Out:
#        ID  age  sex  Anemic_status  Hb_level  managing_anemia  RBC_count  MCV  \
# 0       0   57    1              1     11.49                1       4.49   79
# 1       1   76    1              2      6.02                2       3.20   88
# 2       2   65    0              3      4.14                3       2.45   75
# 3       3   36    0              3      5.46                3       2.13   83
# 4       4   63    0              0     13.56                0       4.96  100
# ..    ...  ...  ...            ...       ...              ...        ...  ...
# 995   995   21    1              3      2.21                3       2.24   81
# 996   996   72    1              0     15.73                0       5.07   96
# 997   997   74    0              3      4.12                3       1.81   70
# 998   998   64    1              2      7.18                2       3.19   77
# 999  1000   45    0              0     15.30                0       4.66   82
#
# ...

# %%
df.insert(17,'infection_status',True)

# %%
def get_infection_status(x):
    if x < 4:
        return 0                        # leucocytopenia
    elif x >= 4 and x < 11:
        return 1                        # normal
    else:
        return 2                        # Leucocytosis

# %%
df['infection_status'] = df['WBC'].apply(lambda x: get_infection_status(x))

# %%
df
# Out:
#        ID  age  sex  Anemic_status  Hb_level  managing_anemia  RBC_count  MCV  \
# 0       0   57    1              1     11.49                1       4.49   79
# 1       1   76    1              2      6.02                2       3.20   88
# 2       2   65    0              3      4.14                3       2.45   75
# 3       3   36    0              3      5.46                3       2.13   83
# 4       4   63    0              0     13.56                0       4.96  100
# ..    ...  ...  ...            ...       ...              ...        ...  ...
# 995   995   21    1              3      2.21                3       2.24   81
# 996   996   72    1              0     15.73                0       5.07   96
# 997   997   74    0              3      4.12                3       1.81   70
# 998   998   64    1              2      7.18                2       3.19   77
# 999  1000   45    0              0     15.30                0       4.66   82
#
# ...

# %%
df['infection_status'].value_counts()
# Out:
# 2    523
# 1    428
# 0     49
# Name: infection_status, dtype: int64

# %%
df.insert(18,'managing_infection',True)

# %%
def how_to_manage_infection(x):
    if x == 0:
        return 0        # 0 - evaluate for the low wbc count i.e low immunity, check for HIV,DM or other immunocompromised state
    elif x == 1:
        return 1        # 1 - normal, nothing to worry
    else:
        return 2        # 2 - '!!!there is infection',find the foci of infection and treat the cause with suitable antibiotics

# %%
df['managing_infection'] = df['infection_status'].apply(lambda x: how_to_manage_infection(x))

# %%
df
# Out:
#        ID  age  sex  Anemic_status  Hb_level  managing_anemia  RBC_count  MCV  \
# 0       0   57    1              1     11.49                1       4.49   79
# 1       1   76    1              2      6.02                2       3.20   88
# 2       2   65    0              3      4.14                3       2.45   75
# 3       3   36    0              3      5.46                3       2.13   83
# 4       4   63    0              0     13.56                0       4.96  100
# ..    ...  ...  ...            ...       ...              ...        ...  ...
# 995   995   21    1              3      2.21                3       2.24   81
# 996   996   72    1              0     15.73                0       5.07   96
# 997   997   74    0              3      4.12                3       1.81   70
# 998   998   64    1              2      7.18                2       3.19   77
# 999  1000   45    0              0     15.30                0       4.66   82
#
# ...

# %%
df.insert(19,'Platelet_count',True)

# %%
Platelet_count = []
for i in range(0,1000):    
    x = round(random.uniform(0.4,6),2)     # normal range of platelets 1.5 - 4 Lakhs/L
    Platelet_count.append(x)

# %%
df['Platelet_count'] = Platelet_count

# %%
df[df['Platelet_count'] < 1.5].value_counts().sum()
# Out:
# 182

# %%
conditions = [
    df['Platelet_count'] < 1.5,
    (df['Platelet_count'] >= 1.5) & (df['Platelet_count'] < 5 ),
    df['Platelet_count'] >= 5
]

choices = [0,1,2]         # 0- Thrombocytopenia     1-normal     2-thrombocytosis

df['Bleeding_status'] = np.select(conditions, choices, default=0)

# %%
df
# Out:
#        ID  age  sex  Anemic_status  Hb_level  managing_anemia  RBC_count  MCV  \
# 0       0   57    1              1     11.49                1       4.49   79
# 1       1   76    1              2      6.02                2       3.20   88
# 2       2   65    0              3      4.14                3       2.45   75
# 3       3   36    0              3      5.46                3       2.13   83
# 4       4   63    0              0     13.56                0       4.96  100
# ..    ...  ...  ...            ...       ...              ...        ...  ...
# 995   995   21    1              3      2.21                3       2.24   81
# 996   996   72    1              0     15.73                0       5.07   96
# 997   997   74    0              3      4.12                3       1.81   70
# 998   998   64    1              2      7.18                2       3.19   77
# 999  1000   45    0              0     15.30                0       4.66   82
#
# ...

# %%
df['Bleeding_status'].value_counts()
# Out:
# 1    623
# 2    195
# 0    182
# Name: Bleeding_status, dtype: int64

# %%
#now manage platelet disorders......
def how_to_manage_platelet_disorder(x):
    if x == 0:       # Thrombocytopenia
        return 0     # evaluate for the cause and if critical, transfuse platelet precipitates or FFP's
    elif x == 1:
        return 1     # normal......nothing to worry
    else:
        return 2     # Thrombocytosis, evaluate for the cause and treat it ....

# %%
df['managing_platelet_disorders'] = df['Bleeding_status'].apply(lambda x: how_to_manage_platelet_disorder(x))

# %%
df
# Out:
#        ID  age  sex  Anemic_status  Hb_level  managing_anemia  RBC_count  MCV  \
# 0       0   57    1              1     11.49                1       4.49   79
# 1       1   76    1              2      6.02                2       3.20   88
# 2       2   65    0              3      4.14                3       2.45   75
# 3       3   36    0              3      5.46                3       2.13   83
# 4       4   63    0              0     13.56                0       4.96  100
# ..    ...  ...  ...            ...       ...              ...        ...  ...
# 995   995   21    1              3      2.21                3       2.24   81
# 996   996   72    1              0     15.73                0       5.07   96
# 997   997   74    0              3      4.12                3       1.81   70
# 998   998   64    1              2      7.18                2       3.19   77
# 999  1000   45    0              0     15.30                0       4.66   82
#
# ...

# %%
Sodium_level = []
for i in range(0,1000):    
    x = random.randint(115,155)     # normal range 125 - 145 mmol/L
    Sodium_level.append(x)
    
Potassium_level = []
for i in range(0,1000):    
    x = round(random.uniform(2.7,5.5),1)    # normal range 3.6 - 5.2 mmol/L
    Potassium_level.append(x)
    
Chloride_level = []
for i in range(0,1000):    
    x = random.randint(86,115)     # normal range 96 - 106 mmol/L
    Chloride_level.append(x)
    
Bicarbonate_level = []
for i in range(0,1000):    
    x = random.randint(16,35)     # normal range 22 - 29 mmol/L
    Bicarbonate_level.append(x)

Blood_urea_level = []
for i in range(0,1000):    
    x = round(random.uniform(1.2,9.0),1)    # normal range 2.1 - 8.5 mmol/L
    Blood_urea_level.append(x)

Serum_creatinine_level = []
for i in range(0,1000):    
    x = round(random.uniform(0.4,6.0),2)     # normal range 0.6 - 1.2 mg/dL
    Serum_creatinine_level.append(x)

# %%
df['Sodium_level'] = Sodium_level
df['Potassium_level'] = Potassium_level
df['Chloride_level'] = Chloride_level
df['Bicarbonate_level'] = Bicarbonate_level
df['Blood_urea_level'] = Blood_urea_level
df['Serum_creatinine_level'] = Serum_creatinine_level

# %%
df
# Out:
#        ID  age  sex  Anemic_status  Hb_level  managing_anemia  RBC_count  MCV  \
# 0       0   57    1              1     11.49                1       4.49   79
# 1       1   76    1              2      6.02                2       3.20   88
# 2       2   65    0              3      4.14                3       2.45   75
# 3       3   36    0              3      5.46                3       2.13   83
# 4       4   63    0              0     13.56                0       4.96  100
# ..    ...  ...  ...            ...       ...              ...        ...  ...
# 995   995   21    1              3      2.21                3       2.24   81
# 996   996   72    1              0     15.73                0       5.07   96
# 997   997   74    0              3      4.12                3       1.81   70
# 998   998   64    1              2      7.18                2       3.19   77
# 999  1000   45    0              0     15.30                0       4.66   82
#
# ...

# %%
df.insert( 28 ,'FPG',True)

# %%
FPG = []
for i in range(0,1000):
    x = random.randint(70, 210)
    FPG.append(x)

# %%
df['FPG'] = FPG

# %%
df
# Out:
#        ID  age  sex  Anemic_status  Hb_level  managing_anemia  RBC_count  MCV  \
# 0       0   57    1              1     11.49                1       4.49   79
# 1       1   76    1              2      6.02                2       3.20   88
# 2       2   65    0              3      4.14                3       2.45   75
# 3       3   36    0              3      5.46                3       2.13   83
# 4       4   63    0              0     13.56                0       4.96  100
# ..    ...  ...  ...            ...       ...              ...        ...  ...
# 995   995   21    1              3      2.21                3       2.24   81
# 996   996   72    1              0     15.73                0       5.07   96
# 997   997   74    0              3      4.12                3       1.81   70
# 998   998   64    1              2      7.18                2       3.19   77
# 999  1000   45    0              0     15.30                0       4.66   82
#
# ...

# %%
df.insert(29,"OGTT",True)

# %%
# real-world dataset may not at all be the same as we are creating now but I want to give intuition of how AI can be made useful.
def get_OGTT(x):
    if x < 100:                                # here, I'm getting values between 100 and 140 for FPG values which are below 100    
        return random.randint(100,140)
    elif x >= 100 and x < 126:                 # here, I'm getting values between 140 and 200 for FPG values which are in range 100-126
        return random.randint(140 ,200)
    else :                                    # here, I'm getting values between 200 and 350 for FPG values which are above 126
        return random.randint(200 ,350)
# The method of getting OGTT values for the given FPG value which is shown here is completely wrong but I want to create the...
#...dataset which is atleast similar to the real world dataset but not the exact one.

# %%
# Set a length of the list to 1000
for i in range(0, 1000):
    df['OGTT'] = df['FPG'].apply(lambda x : get_OGTT(x))

# %%
df.insert(30,'A1C',True)

# %%
#lets get HbA1c values and again, the method which is employed here,is completely wrong but it may be similar to real world dataset..
def A1C(x):
    if x > 200:
        return round(random.uniform(6.5, 8.0), 2)
    elif x in range(140,200):
        return round(random.uniform(5.7, 6.5), 2)
    else:
        return round(random.uniform(4.5, 5.7), 2)

# %%
for i in range(0, 1000):
    df['A1C'] = df['OGTT'].apply(lambda x: A1C(x))

# %%
df.insert(31,"LFT_Diagnosis",True)

# %%
# 0 ---> Normal
# 1 ---> Pre-hepatic jaundice   (Hemolytic jaundice)
# 2 ---> Hepatic jaundice       (Hepatocellular jaundice)
# 3 ---> Post-hepatic jaundice  (Obstructive jaundice)

LFT_Diagnosis = []
for i in range(0,1000):
    x = random.randint(0,3)
    LFT_Diagnosis.append(x)

# %%
df['LFT_Diagnosis'] = LFT_Diagnosis

# %%
df.insert(32,"Conjugated_Bilirubin_count",True)

# %%
def get_Conjugated_Bilirubin_count(x):
    if x == 0:
        return round(random.uniform(0.1,0.3),2)   # normal
    elif x == 1:
        return round(random.uniform(0.1,0.4),2)
    elif x == 2:
        return round(random.uniform(0.4,3.0),2)
    else :
        return round(random.uniform(3,15),2)

# %%
df['Conjugated_Bilirubin_count'] = df['LFT_Diagnosis'].apply(lambda x : round(get_Conjugated_Bilirubin_count(x),2))

# %%
df.insert(33,"Unconjugated_Bilirubin_count",True)

# %%
df.insert(34,"Total_Bilirubin_count",True)

# %%
def get_Total_Bilirubin_count(x):
    if x == 0:
        return round(random.uniform(0.1,1.0),2)
    if x == 1:
        return round(random.uniform(2.5,12),2)
    elif x == 2:
        return round(random.uniform(5,12),2)
    else :
        return round(random.uniform(16,18),2)

# %%
df['Total_Bilirubin_count'] = df['LFT_Diagnosis'].apply(lambda x : round(get_Total_Bilirubin_count(x),2))

# %%
df['Unconjugated_Bilirubin_count'] = df['Total_Bilirubin_count'] - df['Conjugated_Bilirubin_count']

# %%
df.insert(35,"Conjugated/Total_bilirubin_Ratio",True)

# %%
df['Conjugated/Total_bilirubin_Ratio'] = round(df['Conjugated_Bilirubin_count']/df['Total_Bilirubin_count'] * 100,1)

# %%
df.insert(36,"urine_bile_salts",True)

# %%
def get_urine_bile_salts(x):
    if (x == 0) & (x == 1):
        return 0               # absent
    elif x == 2:
        return 1               # minimally present
    else :
        return 2               # heavily present

# %%
df['urine_bile_salts'] = df['LFT_Diagnosis'].apply(lambda x : get_urine_bile_salts(x))

# %%
df.insert(37,"AST",True)

# %%
def get_AST_value(x):
    if x == 1:
        return random.randint(5,40)
    elif x == 2:
        return random.randint(120,200)
    else:
        return random.randint(40,120)

# %%
df['AST'] = df['LFT_Diagnosis'].apply(lambda x : get_AST_value(x))

# %%
df.insert(38,"ALT",True)

# %%
def get_ALT_value(x):
    if x == 1:
        return random.randint(0,25)
    elif x == 2:
        return random.randint(80,200)
    else:
        return random.randint(25,80)

# %%
df['ALT'] = df['LFT_Diagnosis'].apply(lambda x : get_ALT_value(x))

# %%
df.insert(39,"ALP",True)

# %%
def get_ALP_value(x):
    if x == 1:
        return random.randint(30,115)
    elif x == 2:
        return random.randint(115,300)
    else:
        return random.randint(300,1100)

# %%
df['ALP'] = df['LFT_Diagnosis'].apply(lambda x : get_ALP_value(x))

# %%
df.insert(40,"Serum_albumin",True)

# %%
def get_Serum_albumin(x):
    if x == 2:
        return random.uniform(1.5,3.5)    #g/dl
    else:
        return random.uniform(3.5,5.5)

# %%
df['Serum_albumin'] = df['LFT_Diagnosis'].apply(lambda x : round(get_Serum_albumin(x),2))

# %%
df
# Out:
#        ID  age  sex  Anemic_status  Hb_level  managing_anemia  RBC_count  MCV  \
# 0       0   57    1              1     11.49                1       4.49   79
# 1       1   76    1              2      6.02                2       3.20   88
# 2       2   65    0              3      4.14                3       2.45   75
# 3       3   36    0              3      5.46                3       2.13   83
# 4       4   63    0              0     13.56                0       4.96  100
# ..    ...  ...  ...            ...       ...              ...        ...  ...
# 995   995   21    1              3      2.21                3       2.24   81
# 996   996   72    1              0     15.73                0       5.07   96
# 997   997   74    0              3      4.12                3       1.81   70
# 998   998   64    1              2      7.18                2       3.19   77
# 999  1000   45    0              0     15.30                0       4.66   82
#
# ...

# %%
df1 = df.copy()

# %%
df1.columns
# Out:
# Index(['ID', 'age', 'sex', 'Anemic_status', 'Hb_level', 'managing_anemia',
#        'RBC_count', 'MCV', 'HCT', 'MCH', 'MCHC', 'WBC', 'Neutrophils',
#        'Lymphocytes', 'Monocytes', 'Eosinophils', 'Basophils',
#        'infection_status', 'managing_infection', 'Platelet_count',
#        'Bleeding_status', 'managing_platelet_disorders', 'Sodium_level',
#        'Potassium_level', 'Chloride_level', 'Bicarbonate_level',
#        'Blood_urea_level', 'Serum_creatinine_level', 'FPG', 'OGTT', 'A1C',
#        'LFT_Diagnosis', 'Conjugated_Bilirubin_count',
#        'Unconjugated_Bilirubin_count', 'Total_Bilirubin_count',
#        'Conjugated/Total_bilirubin_Ratio', 'urine_bile_salts', 'AST', 'ALT',
#        'ALP', 'Serum_albumin'],
#       dtype='object')

# %%
df1.shape
# Out:
# (1000, 41)

# %%
drop = ['Anemic_status','managing_anemia','managing_infection','infection_status','Bleeding_status',
        'managing_platelet_disorders','LFT_Diagnosis']

# %%
df1.drop(drop,axis=1,inplace=True)

# %%
df1.shape
# Out:
# (1000, 34)

# %%
# Lets save this dataset...
df1.to_csv(r'D:\DSF\PROJECTPRO\MEDICAL_PROJECTS\5.BLOOD_REPORT_WRANGLING\all_reports.csv',index=False)

# %% [markdown]
# ## THANK YOU...
